# %% [markdown]
# ## Simple Portfolio Analysis
#
#
# When it comes to portfolio analysis, there are some key points need to consider:
# - What is the proportion of each stock that combine your portfolio
# - How do the stocks correlated to each other that can highly affected your portfolio performance and the risk management

# %%
import pandas as pd
import numpy as np
import datetime
import vnquant.DataLoader as dl
import investpy

# %%
#Collect the data for your portfolio
#I will use 10 companies as an example of the portfolio in 8 industries: bank, security, insurance, real estate, wholesale, logistics, gas and oil, mineral

company_list = ['TCB','VCB','SSI','BVH','VHM','KBC','MWG','HAH','GAS','HPG',]

# %%
len(company_list)
# Out:
# 10

# %%
#create a dictionary to store the data
d = {}
#stock data
def load_data(symbol):
    start = '2021-01-01'
    
    #you can fix the time frame by using timedelta function of datetime library
    now = datetime.datetime.now()
    end = now.strftime("%Y-%m-%d")
    loader = dl.DataLoader(symbol, start,end, data_source='VND', minimal=True)
    data = loader.download()
    close_data = data['close'].dropna()
    
    
    #to store data remove the '#' on the following line
    #csv_file = close_data.to_csv(f'Data/ClosePrice/{symbol} historical since {start}', index=True)

    return data

# %%
for name in company_list:
    d[name] = load_data(name)
# Out:
# 2022-02-23 21:11:19,672 : INFO : NumExpr defaulting to 8 threads.
# 2022-02-23 21:11:19,682 : INFO : data TCB from 2021-01-01 to 2022-02-23 have already cloned!
# 2022-02-23 21:11:19,922 : INFO : data VCB from 2021-01-01 to 2022-02-23 have already cloned!
# 2022-02-23 21:11:20,174 : INFO : data SSI from 2021-01-01 to 2022-02-23 have already cloned!
# 2022-02-23 21:11:20,419 : INFO : data BVH from 2021-01-01 to 2022-02-23 have already cloned!
# 2022-02-23 21:11:20,695 : INFO : data VHM from 2021-01-01 to 2022-02-23 have already cloned!
# 2022-02-23 21:11:20,955 : INFO : data KBC from 2021-01-01 to 2022-02-23 have already cloned!
# 2022-02-23 21:11:21,204 : INFO : data MWG from 2021-01-01 to 2022-02-23 have already cloned!
# 2022-02-23 21:11:21,494 : INFO : data HAH from 2021-01-01 to 2022-02-23 have already cloned!
# 2022-02-23 21:11:21,773 : INFO : data GAS from 2021-01-01 to 2022-02-23 have already cloned!
# 2022-02-23 21:11:22,039 : INFO : data HPG from 2021-01-01 to 2022-02-23 have already cloned!

# %%
data = d.copy()
data
# Out:
# {'TCB': Attributes   high    low   open  close        avg      volume
#  Symbols       TCB    TCB    TCB    TCB        TCB         TCB
#  date
#  2021-01-04  33.40  31.90  32.00  33.00  32.990000  19689920.0
#  2021-01-05  33.35  32.55  32.75  33.05  33.040000  17622700.0
#  2021-01-06  34.10  32.95  33.20  33.20  33.470000  22676300.0
#  2021-01-07  34.60  33.40  33.75  34.60  34.050000  18078500.0
#  2021-01-08  36.25  34.90  35.00  35.70  35.700000  18919900.0
#  ...           ...    ...    ...    ...        ...         ...
#  2022-02-17  52.50  51.60  51.60  52.20  51.990000   7990000.0
#  2022-02-18  52.00  51.50  51.70  51.60  51.680000   6622600.0
#  2022-02-21  51.70  50.80  51.60  51.50  51.210000  12203200.0
#  2022-02-22  51.70  50.60  51.00  51.40  51.050000  10832900.0
#  2022-02-23  52.20  51.40  51.70  51.70  51.764459   6246800.0
#
#  [282 rows x 6 columns],
#  'VCB': Attributes   high    low   open  close         avg     volume
#  Symbols       VCB    VCB    VCB    VCB         VCB        VCB
#  date
#  2021-01-04   99.8   97.3   98.0   99.0   98.580000   855900.0
#  2021-01-05  100.6   99.0   99.0   99.3   99.910000   739200.0
#  2021-01-06  106.2   99.3   99.5  105.0  103.020000  2080400.0
#  2021-01-07  108.5  104.0  104.0  107.0  106.280000   889000.0
#  2021-01-08  108.0  104.5  108.0  104.8  106.790000   963900.0
#  2021-01-04   89.4   87.1   87.9   88.8   88.140000  1362600.0
#  2021-01-05   90.2   86.6   88.0   90.0   89.330000  1262700.0
#  2021-01-06   91.9   90.0   91.0   90.4   91.080000  1196900.0
#  2021-01-07   92.8   89.2   91.0   92.7   90.900000  1509300.0
#  2021-01-08   93.3   91.7   92.7   92.7   92.680000   934700.0
#  ...           ...    ...    ...    ...         ...        ...
#  2022-02-17  118.7  113.7  114.4  118.7  116.520000  1128100.0
#  2022-02-18  118.7  115.3  116.5  117.0  117.070000   732400.0
#  2022-02-21  117.0  115.5  116.5  115.8  116.010000   332600.0
#  2022-02-22  118.5  116.0  118.0  116.5  117.550000   721200.0
#  2022-02-23  120.5  116.3  117.6  117.0  118.898692  1292100.0
#
#  [282 rows x 6 columns],
#  'HPG': Attributes   high    low   open  close        avg      volume
#  Symbols       HPG    HPG    HPG    HPG        HPG         HPG
#  date
#  2021-01-04  43.00  41.65  42.00  42.30  42.450000  17422606.0
#  2021-01-05  42.80  41.70  41.80  42.35  42.160000  18634100.0
#  2021-01-06  43.30  42.30  42.50  42.80  42.740000  19818600.0
#  2021-01-07  43.20  42.25  43.15  42.80  42.680000  25867000.0
#  2021-01-08  43.30  42.60  42.90  42.75  42.910000  20555400.0
#  ...           ...    ...    ...    ...        ...         ...
#  2022-02-17  46.75  46.00  46.00  46.50  46.400000  12373600.0
#  2022-02-18  47.65  46.05  46.20  47.05  47.130000  23135500.0
#  2022-02-21  47.50  46.55  47.10  46.65  46.960000  12177300.0
#  2022-02-22  46.60  45.70  46.30  46.40  46.100000  21134900.0
#  2022-02-23  47.20  46.25  46.65  46.70  46.629947  12981100.0
#
#  [282 rows x 6 columns]}

# %%
#Slice to get needed data
for name in company_list:
    data[name]['Pctchange'] = data[name].close.pct_change()
    data[name] = data[name]['Pctchange'].values
    
#create dataframe from dictionary
df_change = pd.DataFrame({name:list(pct_change) for name,pct_change in data.items()})
df_change.dropna(inplace=True)
df_change
# Out:
#           TCB       VCB       SSI       BVH       VHM       KBC       MWG  \
# 1    0.001515  0.003030 -0.001479 -0.004525  0.039130  0.034483  0.010779
# 2    0.004539  0.057402  0.007407  0.007576 -0.008368 -0.029630 -0.004922
# 3    0.042169  0.019048  0.011765  0.007519  0.000000  0.030534 -0.004122
# 4    0.031792 -0.020561 -0.007267  0.019403  0.016878  0.018519  0.008278
# 5   -0.012605 -0.002863 -0.017570 -0.002928  0.069502  0.025455  0.036125
# ..        ...       ...       ...       ...       ...       ...       ...
# 277  0.011628  0.005747  0.002227 -0.008711  0.010000  0.013865  0.012039
# 278 -0.011494 -0.003429  0.004444  0.007030 -0.013614  0.000000 -0.003717
# 279 -0.001938  0.002294  0.017699 -0.001745  0.003764  0.000000 -0.000746
# 280 -0.001942 -0.006865 -0.021739 -0.015734 -0.008750 -0.029060  0.028379
# 281  0.005837  0.001152  0.006667  0.023091  0.001261  0.008803  0.000726
#
#           HAH       GAS       HPG
# 1   -0.005391  0.013514  0.001182
# 2   -0.016260  0.004444  0.010626
# 3    0.068871  0.025442  0.000000
# 4    0.005155  0.000000 -0.001168
# 5    0.005128  0.006472  0.007018
# ..        ...       ...       ...
# 277  0.066207  0.036681  0.010870
# 278  0.046572 -0.014322  0.011828
# 279 -0.011125 -0.010256 -0.008502
# 280 -0.002500  0.006045 -0.005359
# 281 -0.012531  0.004292  0.006466
#
# [281 rows x 10 columns]

# %%
#correlation by daily percentage change of each stock
corr = df_change.corr()
corr
# Out:
#           TCB       VCB       SSI       BVH       VHM       KBC       MWG  \
# TCB  1.000000  0.422088  0.527811  0.428594  0.392241  0.330010  0.301042
# VCB  0.422088  1.000000  0.288693  0.311407  0.312548  0.156856  0.181814
# SSI  0.527811  0.288693  1.000000  0.471092  0.388175  0.414422  0.215039
# BVH  0.428594  0.311407  0.471092  1.000000  0.396006  0.513539  0.190778
# VHM  0.392241  0.312548  0.388175  0.396006  1.000000  0.359432  0.300207
# KBC  0.330010  0.156856  0.414422  0.513539  0.359432  1.000000  0.200147
# MWG  0.301042  0.181814  0.215039  0.190778  0.300207  0.200147  1.000000
# HAH  0.247335  0.105792  0.315722  0.296998  0.234434  0.194414  0.150553
# GAS  0.380288  0.257191  0.351470  0.419846  0.289870  0.393735  0.264947
# HPG  0.495212  0.354110  0.339634  0.420126  0.338266  0.379995  0.244095
#
#           HAH       GAS       HPG
# TCB  0.247335  0.380288  0.495212
# VCB  0.105792  0.257191  0.354110
# SSI  0.315722  0.351470  0.339634
# BVH  0.296998  0.419846  0.420126
# VHM  0.234434  0.289870  0.338266
# KBC  0.194414  0.393735  0.379995
# MWG  0.150553  0.264947  0.244095
# HAH  1.000000  0.281155  0.256532
# GAS  0.281155  1.000000  0.390915
# HPG  0.256532  0.390915  1.000000

# %%
#correlation heatmap for stock in the portfolio
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
# #T_c0b25_row0_col0,#T_c0b25_row1_col1,#T_c0b25_row2_col2,#T_c0b25_row3_col3,#T_c0b25_row4_col4,#T_c0b25_row5_col5,#T_c0b25_row6_col6,#T_c0b25_row7_col7,#T_c0b25_row8_col8,#T_c0b25_row9_col9{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_c0b25_row0_col1{
#             background-color:  #b1cbfc;
#             color:  #000000;
#         }#T_c0b25_row0_col2,#T_c0b25_row5_col3{
#             background-color:  #c0d4f5;
#             color:  #000000;
#         }#T_c0b25_row0_col3{
#             background-color:  #9dbdff;
#             color:  #000000;
#         }#T_c0b25_row0_col4,#T_c0b25_row0_col5,#T_c0b25_row2_col1{
#             background-color:  #7da0f9;
#             color:  #000000;
#         }#T_c0b25_row0_col6,#T_c0b25_row4_col6,#T_c0b25_row8_col0{
#             background-color:  #7396f5;
#             color:  #000000;
#         }#T_c0b25_row0_col7,#T_c0b25_row9_col2{
#             background-color:  #6c8ff1;
#             color:  #000000;
#         }#T_c0b25_row0_col8{
#             background-color:  #6f92f3;
#             color:  #000000;
#         }#T_c0b25_row0_col9{
#             background-color:  #aac7fd;
#             color:  #000000;
#         }#T_c0b25_row1_col0,#T_c0b25_row3_col9,#T_c0b25_row4_col1{
#             background-color:  #86a9fc;
#             color:  #000000;
#         }#T_c0b25_row1_col2{
#             background-color:  #5875e1;
#             color:  #000000;
#         }#T_c0b25_row1_col3{
#             background-color:  #6a8bef;
#             color:  #000000;
#         }#T_c0b25_row1_col4{
#             background-color:  #5a78e4;
#             color:  #000000;
#         }#T_c0b25_row1_col5,#T_c0b25_row1_col7,#T_c0b25_row1_col8,#T_c0b25_row6_col2,#T_c0b25_row6_col3,#T_c0b25_row6_col9,#T_c0b25_row7_col0,#T_c0b25_row7_col1,#T_c0b25_row7_col4,#T_c0b25_row7_col6{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_c0b25_row1_col6{
#             background-color:  #455cce;
#             color:  #f1f1f1;
#         }#T_c0b25_row1_col9{
#             background-color:  #688aef;
#             color:  #000000;
#         }#T_c0b25_row2_col0{
#             background-color:  #b7cff9;
#             color:  #000000;
#         }#T_c0b25_row2_col3{
#             background-color:  #aec9fc;
#             color:  #000000;
#         }#T_c0b25_row2_col4{
#             background-color:  #7b9ff9;
#             color:  #000000;
#         }#T
#             background-color:  #b3d6e8;
#             color:  #000000;
#         }#T_90f96_row0_col2,#T_90f96_row5_col3{
#             background-color:  #d1e5f0;
#             color:  #000000;
#         }#T_90f96_row0_col3{
#             background-color:  #8dc2dc;
#             color:  #000000;
#         }#T_90f96_row0_col4,#T_90f96_row0_col5,#T_90f96_row2_col1{
#             background-color:  #4695c4;
#             color:  #000000;
#         }#T_90f96_row0_col6,#T_90f96_row4_col6,#T_90f96_row8_col0{
#             background-color:  #3b88be;
#             color:  #000000;
#         }#T_90f96_row0_col7,#T_90f96_row9_col2{
#             background-color:  #3480b9;
#             color:  #000000;
#         }#T_90f96_row0_col8{
#             background-color:  #3783bb;
#             color:  #000000;
#         }#T_90f96_row0_col9{
#             background-color:  #a7d0e4;
#             color:  #000000;
#         }#T_90f96_row1_col0,#T_90f96_row3_col9,#T_90f96_row4_col1{
#             background-color:  #5ca3cb;
#             color:  #000000;
#         }#T_90f96_row1_col2{
#             background-color:  #1f63a8;
#             color:  #f1f1f1;
#         }#T_90f96_row1_col3{
#             background-color:  #327cb7;
#             color:  #000000;
#         }#T_90f96_row1_col4{
#             background-color:  #2267ac;
#             color:  #f1f1f1;
#         }#T_90f96_row1_col5,#T_90f96_row1_col7,#T_90f96_row1_col8,#T_90f96_row6_col2,#T_90f96_row6_col3,#T_90f96_row6_col9,#T_90f96_row7_col0,#T_90f96_row7_col1,#T_90f96_row7_col4,#T_90f96_row7_col6{
#             background-color:  #053061;
#             color:  #f1f1f1;
#         }#T_90f96_row1_col6{
#             background-color:  #0f437b;
#             color:  #f1f1f1;
#         }#T_90f96_row1_col9{
#             background-color:  #307ab6;
#             color:  #000000;
#         }#T_90f96_row2_col0{
#             background-color:  #c0dceb;
#             color:  #000000;
#         }#T_90f96_row2_col3{
#             background-color:  #aed3e6;
#             color:  #000000;
#         }#T_90f96_row2_col4{
#             background-color:  #4393c3;
#             color:  #000000;
#         }#T_90f96_row2_col5{
#             background-color:  #96c7df;
#             color:  #000000;
#         }#T_90f96_row2_col6{
#             background-color:  #1a5899;
#             color:  #f1f1f1;
#         }#T_90f96_row2_col7{
#             background-color:  #5fa5cd;
#             color:  #000000;
#         }#T_90f96_row2_col8,#T_90f96_row2_col9,#T_90f96_row7_col2{
#             background-color:  #2a71b2;
#             color:  #f1f1f1;
#         }#T_90f96_row3_col0,#T_90f96_row4_col5{
#             background-color:  #62a7ce;
#             color:  #000000;
#         }#T_90f96_row3_col1{
#             background-color:  #59a1ca;
#             color:  #000000;
#         }#T_90f96_row3_col2{
#             background-color:  #a2cde3;
#             color:  #000000;
#         }#T_90f96_row3_col4,#T_90f96_row3_col7{
#             background-color:  #4c99c6;
#             color:  #000000;
#         }#T_90f96_row3_col5{
#             background-color:  #dae9f2;
#             color:  #000000;
#         }#T_90f96_row3_col6,#T_90f96_row6_col7{
#             background-color:  #124984;
#             color:  #f1f1f1;
#         }#T_90f96_row3_col8,#T_90f96_row4_col2{
#             background-color:  #529dc8;
#             color:  #000000;
#         }#T_90f96_row4_col0,#T_90f96_row8_col9{
#             background-color:  #408fc1;
#             color:  #000000;
#         }#T_90f96_row4_col3{
#             background-color:  #6bacd1;
#             color:  #000000;
#         }#T_90f96_row4_col7{
#             background-color:  #2f79b5;
#             color:  #000000;
#         }#T_90f96_row4_col8,#T_90f96_row7_col5{
#             background-color:  #114781;
#             color:  #f1f1f1;
#         }#T_90f96_row4_col9{
#             background-color:  #2870b1;
#             color:  #f1f1f1;
#         }#T_90f96_row5_col0,#T_90f96_row9_col6{
#             background-color:  #246aae;
#             color:  #f1f1f1;
#         }#T_90f96_row5_col1,#T_90f96_row5_col6{
#             background-color:  #144e8a;
#             color:  #f1f1f1;
#         }#T_90f96_row5_col2{
#             background-color:  #6eaed2;
#             color:  #000000;
#         }#T_90f96_row5_col4{
#             background-color:  #3681ba;
#             color:  #000000;
#         }#T_90f96_row5_col7{
#             background-color:  #2065ab;
#             color:  #f1f1f1;
#         }#T_90f96_row5_col8{
#             background-color:  #3e8cbf;
#             color:  #000000;
#         }#T_90f96_row5_col9,#T_90f96_row9_col8{
#             background-color:  #3c8abe;
#             color:  #000000;
#         }#T_90f96_row6_col0,#T_90f96_row8_col4{
#             background-color:  #195696;
#             color:  #f1f1f1;
#         }#T_90f96_row6_col1,#T_90f96_row6_col4{
#             background-color:  #1c5c9f;
#             color:  #f1f1f1;
#         }#T_90f96_row6_col5{
#             background-color:  #134c87;
#             color:  #f1f1f1;
#         }#T_90f96_row6_col8{
#             background-color:  #073467;
#             color:  #f1f1f1;
#         }#T_90f96_row7_col3{
#             background-color:  #2b73b3;
#             color:  #000000;
#         }#T_90f96_row7_col8{
#             background-color:  #0e4179;
#             color:  #f1f1f1;
#         }#T_90f96_row7_col9{
#             background-color:  #09386d;
#             color:  #f1f1f1;
#         }#T_90f96_row8_col1,#T_90f96_row9_col7{
#             background-color:  #3885bc;
#             color:  #000000;
#         }#T_90f96_row8_col2{
#             background-color:  #3a87bd;
#             color:  #000000;
#         }#T_90f96_row8_col3,#T_90f96_row9_col3{
#             background-color:  #84bcd9;
#             color:  #000000;
#         }#T_90f96_row8_col5,#T_90f96_row9_col1{
#             background-color:  #81bad8;
#             color:  #000000;
#         }#T_90f96_row8_col6,#T_90f96_row9_col4{
#             background-color:  #2c75b4;
#             color:  #000000;
#         }#T_90f96_row8_col7{
#             background-color:  #4291c2;
#             color:  #000000;
#         }#T_90f96_row9_col0{
#             background-color:  #a5cee3;
#             color:  #000000;
#         }#T_90f96_row9_col5{
#             background-color:  #75b2d4;
#             color:  #000000;
#         }</style><table id="T_90f96_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >TCB</th>        <th class="col_heading level0 col1" >VCB</th>        <th class="col_heading level0 col2" >SSI</th>        <th class="col_heading level0 col3" >BVH</th>        <th class="col_heading level0 col4" >VHM</th>        <th class="col_heading level0 col5" >KBC</th>        <th class="col_heading level0 col6" >MWG</th>        <th class="col_heading level0 col7" >HAH</th>        <th class="col_heading level0 col8" >GAS</th>        <th class="col_heading level0 col9" >HPG</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_90f96_level0_row0" class="row_heading level0 row0" >TCB</th>
#                         <td id="T_90f96_row0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_90f96_row0_col1" class="data row0 col1" >0.422088</td>
#                         <td id="T_90f96_row0_col2" class="data row0 col2" >0.527811</td>
#                         <td id="T_90f96_row0_col3" class="data row0 col3" >0.428594</td>
#                         <td id="T_90f96_row0_col4" class="data row0 col4" >0.392241</td>
#                         <td id="T_90f96_row0_col5" class="data row0 col5" >0.330010</td>
#                         <td id="T_90f96_row0_col6" class="data row0 col6" >0.301042</td>
#                         <td id="T_90f96_row0_col7" class="data row0 col7" >0.247335</td>
#                         <td id="T_90f96_row0_col8" class="data row0 col8" >0.380288</td>

# %%
#different stle
corr.style.background_gradient(cmap='BrBG_r')
# Out:
# <style  type="text/css" >
# #T_dcbbf_row0_col0,#T_dcbbf_row1_col1,#T_dcbbf_row2_col2,#T_dcbbf_row3_col3,#T_dcbbf_row4_col4,#T_dcbbf_row5_col5,#T_dcbbf_row6_col6,#T_dcbbf_row7_col7,#T_dcbbf_row8_col8,#T_dcbbf_row9_col9{
#             background-color:  #543005;
#             color:  #f1f1f1;
#         }#T_dcbbf_row0_col1{
#             background-color:  #a6dcd4;
#             color:  #000000;
#         }#T_dcbbf_row0_col2,#T_dcbbf_row5_col3{
#             background-color:  #c7eae5;
#             color:  #000000;
#         }#T_dcbbf_row0_col3{
#             background-color:  #7ccabe;
#             color:  #000000;
#         }#T_dcbbf_row0_col4,#T_dcbbf_row0_col5,#T_dcbbf_row2_col1{
#             background-color:  #389991;
#             color:  #000000;
#         }#T_dcbbf_row0_col6,#T_dcbbf_row4_col6,#T_dcbbf_row8_col0{
#             background-color:  #298b83;
#             color:  #000000;
#         }#T_dcbbf_row0_col7,#T_dcbbf_row9_col2{
#             background-color:  #1f827a;
#             color:  #000000;
#         }#T_dcbbf_row0_col8{
#             background-color:  #23867e;
#             color:  #000000;
#         }#T_dcbbf_row0_col9{
#             background-color:  #98d7cd;
#             color:  #000000;
#         }#T_dcbbf_row1_col0,#T_dcbbf_row3_col9,#T_dcbbf_row4_col1{
#             background-color:  #4da89f;
#             color:  #000000;
#         }#T_dcbbf_row1_col2{
#             background-color:  #01645b;
#             color:  #f1f1f1;
#         }#T_dcbbf_row1_col3{
#             background-color:  #1a7e76;
#             color:  #000000;
#         }#T_dcbbf_row1_col4{
#             background-color:  #02675f;
#             color:  #f1f1f1;
#         }#T_dcbbf_row1_col5,#T_dcbbf_row1_col7,#T_dcbbf_row1_col8,#T_dcbbf_row6_col2,#T_dcbbf_row6_col3,#T_dcbbf_row6_col9,#T_dcbbf_row7_col0,#T_dcbbf_row7_col1,#T_dcbbf_row7_col4,#T_dcbbf_row7_col6{
#             background-color:  #003c30;
#             color:  #f1f1f1;
#         }#T_dcbbf_row1_col6{
#             background-color:  #004b40;
#             color:  #f1f1f1;
#         }#T_dcbbf_row1_col9{
#             background-color:  #187c74;
#             color:  #f1f1f1;
#         }#T_dcbbf_row2_col0{
#             background-color:  #b4e2db;
#             color:  #000000;
#         }#T_dcbbf_row2_col3{
#             background-color:  #a0dad1;
#             color:  #000000;
#         }#T_dcbbf_row2_col4{
#             background-color:  #35978f;
#             color:  #000000;
#         }#T_dcbbf_row2_col5{
#             background-color:  #84cfc3;
#             color:  #000000;
#         }#T_dcbbf_row2_col6{
#             background-color:  #015b52;
#             color:  #f1f1f1;
#         }#T_dcbbf_row2_col7{
#             background-color:  #4faaa1;
#             color:  #000000;
#         }#T_dcbbf_row2_col8,#T_dcbbf_row2_col9,#T_dcbbf_row7_col2{
#             background-color:  #0e726a;
#             color:  #f1f1f1;
#         }#T_dcbbf_row3_col0,#T_dcbbf_row4_col5{
#             background-color:  #52aca3;
#             color:  #000000;
#         }#T_dcbbf_row3_col1{
#             background-color:  #4aa69d;
#             color:  #000000;
#         }#T_dcbbf_row3_col2{
#             background-color:  #92d4ca;
#             color:  #000000;
#         }#T_dcbbf_row3_col4,#T_dcbbf_row3_col7{
#             background-color:  #3e9d95;
#             color:  #000000;
#         }#T_dcbbf_row3_col5{
#             background-color:  #d2ede9;
#             color:  #000000;
#         }#T_dcbbf_row3_col6,#T_dcbbf_row6_col7{
#             background-color:  #005046;
#             color:  #f1f1f1;
#         }#T_dcbbf_row3_col8,#T_dcbbf_row4_col2{
#             background-color:  #44a299;
#             color:  #000000;
#         }#T_dcbbf_row4_col0,#T_dcbbf_row8_col9{
#             background-color:  #31938b;
#             color:  #000000;
#         }#T_dcbbf_row4_col3{
#             background-color:  #5bb3a8;
#             color:  #000000;
#         }#T_dcbbf_row4_col7{
#             background-color:  #167a72;
#             color:  #f1f1f1;
#         }#T_dcbbf_row4_col8,#T_dcbbf_row7_col5{
#             background-color:  #004e44;
#             color:  #f1f1f1;
#         }#T_dcbbf_row4_col9{
#             background-color:  #0c7169;
#             color:  #f1f1f1;
#         }#T_dcbbf_row5_col0,#T_dcbbf_row9_col6{
#             background-color:  #066b63;
#             color:  #f1f1f1;
#         }#T_dcbbf_row5_col1,#T_dcbbf_row5_col6{
#             background-color:  #015349;
#             color:  #f1f1f1;
#         }#T_dcbbf_row5_col2{
#             background-color:  #5eb5aa;
#             color:  #000000;
#         }#T_dcbbf_row5_col4{
#             background-color:  #21847c;
#             color:  #000000;
#         }#T_dcbbf_row5_col7{
#             background-color:  #01655d;
#             color:  #f1f1f1;
#         }#T_dcbbf_row5_col8{
#             background-color:  #2d8f87;
#             color:  #000000;
#         }#T_dcbbf_row5_col9,#T_dcbbf_row9_col8{
#             background-color:  #2b8d85;
#             color:  #000000;
#         }#T_dcbbf_row6_col0,#T_dcbbf_row8_col4{
#             background-color:  #015a50;
#             color:  #f1f1f1;
#         }#T_dcbbf_row6_col1,#T_dcbbf_row6_col4{
#             background-color:  #015f56;
#             color:  #f1f1f1;
#         }#T_dcbbf_row6_col5{
#             background-color:  #015147;
#             color:  #f1f1f1;
#         }#T_dcbbf_row6_col8{
#             background-color:  #003f34;
#             color:  #f1f1f1;
#         }#T_dcbbf_row7_col3{
#             background-color:  #10746c;
#             color:  #f1f1f1;
#         }#T_dcbbf_row7_col8{
#             background-color:  #00493e;
#             color:  #f1f1f1;
#         }#T_dcbbf_row7_col9{
#             background-color:  #004337;
#             color:  #f1f1f1;
#         }#T_dcbbf_row8_col1,#T_dcbbf_row9_col7{
#             background-color:  #258880;
#             color:  #000000;
#         }#T_dcbbf_row8_col2{
#             background-color:  #278a82;
#             color:  #000000;
#         }#T_dcbbf_row8_col3,#T_dcbbf_row9_col3{
#             background-color:  #73c3b8;
#             color:  #000000;
#         }#T_dcbbf_row8_col5,#T_dcbbf_row9_col1{
#             background-color:  #70c1b6;
#             color:  #000000;
#         }#T_dcbbf_row8_col6,#T_dcbbf_row9_col4{
#             background-color:  #12766e;
#             color:  #f1f1f1;
#         }#T_dcbbf_row8_col7{
#             background-color:  #33958d;
#             color:  #000000;
#         }#T_dcbbf_row9_col0{
#             background-color:  #95d6cc;
#             color:  #000000;
#         }#T_dcbbf_row9_col5{
#             background-color:  #64b9ae;
#             color:  #000000;
#         }</style><table id="T_dcbbf_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >TCB</th>        <th class="col_heading level0 col1" >VCB</th>        <th class="col_heading level0 col2" >SSI</th>        <th class="col_heading level0 col3" >BVH</th>        <th class="col_heading level0 col4" >VHM</th>        <th class="col_heading level0 col5" >KBC</th>        <th class="col_heading level0 col6" >MWG</th>        <th class="col_heading level0 col7" >HAH</th>        <th class="col_heading level0 col8" >GAS</th>        <th class="col_heading level0 col9" >HPG</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_dcbbf_level0_row0" class="row_heading level0 row0" >TCB</th>
#                         <td id="T_dcbbf_row0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_dcbbf_row0_col1" class="data row0 col1" >0.422088</td>
#                         <td id="T_dcbbf_row0_col2" class="data row0 col2" >0.527811</td>
#                         <td id="T_dcbbf_row0_col3" class="data row0 col3" >0.428594</td>
#                         <td id="T_dcbbf_row0_col4" class="data row0 col4" >0.392241</td>
#                         <td id="T_dcbbf_row0_col5" class="data row0 col5" >0.330010</td>
#                         <td id="T_dcbbf_row0_col6" class="data row0 col6" >0.301042</td>
#                         <td id="T_dcbbf_row0_col7" class="data row0 col7" >0.247335</td>
#                         <td id="T_dcbbf_row0_col8" class="data row0 col8" >0.380288</td>

# %% [markdown]
# ### Stock portfolio allocation
# In this notebook, I will present 2 ways to allocate this portfolio:
# - Equal weighted portfolio
# - Capitalized weighted portfolio
#
# Equal weighted portfolio is quite easy to build, for example in this portfolio, just buy 10% of your NAV in order to achieve this goal. On the other hand, capitalized weighted portfolio build on each stock's capitalization.
# So the problem here is to calculate the capitalization, or for an easier life, use the data from the third party : ). For the n time, we can use investpy or third party API

# %%
### Using the riskanalysis class from the risk analysis section
class risk_analysis(object):
    def __init__(self, stock_name, index_name, start_date):
        self.stock_name = stock_name
        self.index_name = index_name
        self.start_date = start_date



    def get_data_stock(self,stock_name, start_date):
        start_date = start_date
        end_date = datetime.datetime.today().strftime('%Y-%m-%d')
        loader = dl.DataLoader(stock_name , start_date, end_date, data_source='VND', minimal=True)
        data = loader.download()
        return data



    def get_index_data(self,index_name, start_date):
        start_date = datetime.datetime.strptime(start_date,'%Y-%m-%d').strftime('%d/%m/%Y')
        end_date = datetime.datetime.today().strftime('%d/%m/%Y')

        index = investpy.get_index_historical_data(index_name,country='vietnam',from_date=start_date,to_date=end_date)

        return index

    def data_collection(self):

        # Get index data
        index = self.get_index_data(self.index_name, self.start_date)
        index_data = index.reset_index()
        index_data = index_data.rename(columns={'Date':'date','Open':'open' ,'Close':'close','High':'high','Low':'low','Volume':'volume'})
        index_data['date'] = pd.to_datetime(index_data['date'])
        index_data = index_data.set_index('date')
        index_data = index_data.drop('Currency', axis=1)
        index_data['pctchange'] = index_data['close'].pct_change()
        index_data.dropna(inplace=True)


        # Get stock data
        stock = self.get_data_stock(self.stock_name, self.start_date)
        stock_data = stock.reset_index()
        stock_data = stock_data.rename(columns={'Date':'date', 'Close':'close'})
        stock_data['date'] = pd.to_datetime(stock_data['date'])
        stock_data = stock_data.set_index('date')
        stock_data = stock_data[['open','high','low','close','volume']]
        stock_data['pctchange'] = stock_data['close'].pct_change()
        stock_data.dropna(inplace=True)

        self.index_data = index_data
        self.stock_data = stock_data

        return self.index_data, self.stock_data

    def calculate_std(self):
        index_data, stock_data = self.data_collection()

        # Calculate variance
        #var_stock = round(float(['pctchange'].var()),5)
        # Calculate standard deviation
        def variance(data, ddof=0):
            n = len(data)
            mean = sum(data) / n

            return sum((x - mean) ** 2 for x in data) / (n - ddof)

        var_stock = round(variance(stock_data['pctchange']),5)
        var_stock = var_stock * 100

        stock_variance = 'Variance: ' + str(var_stock).format('.2f') + '%'

        std_stock = round(float(stock_data['pctchange'].std()),5)
        std_stock = std_stock * 100
        stock_std_deviation = 'Standard deviation: ' + str(std_stock).format('.2f') + '%'

        return stock_std_deviation

    def calculate_beta(self):
        index_data, stock_data = self.data_collection()

        # Calculate beta
        def beta(data, data_index):
            return np.cov(data, data_index)[0, 1] / np.var(data_index)

        beta_stock = beta(stock_data['pctchange'], index_data['pctchange'])
        beta_stock = round(beta_stock,5)

  

        return beta_stock

    def calculate_alpha(self):
        index_data, stock_data = self.data_collection()
        def beta(data, data_index):
            return np.cov(data, data_index)[0, 1] / np.var(data_index)

        # Calculate alpha
        def alpha(data, data_index):
            return np.mean(data) - beta(data, data_index) * np.mean(data_index)

        alpha_stock = alpha(stock_data['pctchange'], index_data['pctchange'])
        alpha_stock = round(alpha_stock,5) *100

        stock_alpha = 'Alpha: ' + str(alpha_stock).format('.2f') + '%'

        return stock_alpha

    def calculate_rsquared(self):
        index_data, stock_data = self.data_collection()

        # Calculate rsquared
        def rsquared(data, data_index):
            return 1 - (np.var(data) / np.var(data_index))

        rsquared_stock = rsquared(stock_data['pctchange'], index_data['pctchange'])
        rsquared_stock = round(rsquared_stock,5)

        stock_rsquared = 'Rsquared: ' + str(rsquared_stock).format('.2f')

        return stock_rsquared

    def calculate_correlation(self):
        index_data, stock_data = self.data_collection()

        # Calculate correlation
        def correlation(data, data_index):
            return np.corrcoef(data, data_index)[0, 1]

        correlation_stock = correlation(stock_data['pctchange'], index_data['pctchange'])
        correlation_stock = round(correlation_stock,5)

        stock_correlation = 'Correlation: ' + str(correlation_stock).format('.2f')

        return stock_correlation

# %% [markdown]
# #### Calculating portfolio beta

# %%
company_list
# Out:
# ['TCB', 'VCB', 'SSI', 'BVH', 'VHM', 'KBC', 'MWG', 'HAH', 'GAS', 'HPG']

# %%
#create dataframe for equal
equal_weighted = pd.DataFrame(index = company_list,columns=['Weight','Beta','AdjBeta'])

# %%
equal_weighted['Weight'] = 0.1 ##Set the same weight for each stock , in this example, each one has 10%
equal_weighted
# Out:
#      Weight Beta AdjBeta
# TCB     0.1  NaN     NaN
# VCB     0.1  NaN     NaN
# SSI     0.1  NaN     NaN
# BVH     0.1  NaN     NaN
# VHM     0.1  NaN     NaN
# KBC     0.1  NaN     NaN
# MWG     0.1  NaN     NaN
# HAH     0.1  NaN     NaN
# GAS     0.1  NaN     NaN
# HPG     0.1  NaN     NaN

# %%
#Collecting data and calculate beta for each symbol
index = 'VN'
start = '2021-01-01'
#create dictionary for company's beta
Beta = {}
for name in company_list:
    company = risk_analysis(name,index, start)
    beta = float(company.calculate_beta())
    Beta[name] = beta
# Out:
# 2022-02-23 21:11:35,607 : INFO : data TCB from 2021-01-01 to 2022-02-23 have already cloned!
# 2022-02-23 21:11:37,387 : INFO : data VCB from 2021-01-01 to 2022-02-23 have already cloned!
# 2022-02-23 21:11:39,133 : INFO : data SSI from 2021-01-01 to 2022-02-23 have already cloned!
# 2022-02-23 21:11:40,758 : INFO : data BVH from 2021-01-01 to 2022-02-23 have already cloned!
# 2022-02-23 21:11:42,404 : INFO : data VHM from 2021-01-01 to 2022-02-23 have already cloned!
# 2022-02-23 21:11:44,062 : INFO : data KBC from 2021-01-01 to 2022-02-23 have already cloned!
# 2022-02-23 21:11:45,094 : INFO : data MWG from 2021-01-01 to 2022-02-23 have already cloned!
# 2022-02-23 21:11:46,818 : INFO : data HAH from 2021-01-01 to 2022-02-23 have already cloned!
# 2022-02-23 21:11:48,577 : INFO : data GAS from 2021-01-01 to 2022-02-23 have already cloned!
# 2022-02-23 21:11:50,280 : INFO : data HPG from 2021-01-01 to 2022-02-23 have already cloned!

# %%
Be = Beta.copy()
df_beta=pd.DataFrame.from_dict(Be,orient='index')
df_beta
# Out:
#            0
# TCB  1.26720
# VCB  0.92541
# SSI  1.69273
# BVH  1.07070
# VHM  1.15963
# KBC  1.44860
# MWG  0.82737
# HAH  0.86995
# GAS  1.06322
# HPG  1.22213

# %%
l = []
for i in range(0,len(company_list)):
    l.append(x[i][1])

# %%
df_beta
# Out:
#            0
# TCB  1.26720
# VCB  0.92541
# SSI  1.69273
# BVH  1.07070
# VHM  1.15963
# KBC  1.44860
# MWG  0.82737
# HAH  0.86995
# GAS  1.06322
# HPG  1.22213

# %%
#Filling dataframe

equal_weighted['Beta'] = df_beta.values
equal_weighted['AdjBeta'] = equal_weighted['Weight']*equal_weighted['Beta']
equal_weighted
# Out:
#      Weight     Beta   AdjBeta
# TCB     0.1  1.26720  0.126720
# VCB     0.1  0.92541  0.092541
# SSI     0.1  1.69273  0.169273
# BVH     0.1  1.07070  0.107070
# VHM     0.1  1.15963  0.115963
# KBC     0.1  1.44860  0.144860
# MWG     0.1  0.82737  0.082737
# HAH     0.1  0.86995  0.086995
# GAS     0.1  1.06322  0.106322
# HPG     0.1  1.22213  0.122213

# %%
#Portfolio beta
portfolio_beta = equal_weighted['AdjBeta'].sum()
equal_weight_beta = 'Your portfolio beta is: '+ str(portfolio_beta)+ ' which is made from '+ ', '.join(map(str, company_list))

# %%
print(equal_weight_beta)
# Out:
# Your portfolio beta is: 1.1546939999999999 which is made from TCB, VCB, SSI, BVH, VHM, KBC, MWG, HAH, GAS, HPG

# %%
#Capitalized weighted
#using list to collect market cap data
cap=[]
for name in company_list:
    stock = investpy.get_stock_information(stock =name ,country = 'vietnam')
    print(stock['Market Cap'])
    cap.append(stock['Market Cap'])
# Out:
# 0    1.815100e+14
# Name: Market Cap, dtype: float64
# 0    4.112600e+14
# Name: Market Cap, dtype: float64
# 0    4.452000e+13
# Name: Market Cap, dtype: float64
# 0    4.276000e+13
# Name: Market Cap, dtype: float64
# 0    3.457400e+14
# Name: Market Cap, dtype: float64
# 0    3.265000e+13
# Name: Market Cap, dtype: float64
# 0    9.824000e+13
# Name: Market Cap, dtype: float64
# 0    3.840000e+12
# Name: Market Cap, dtype: float64
# 0    2.239300e+14
# Name: Market Cap, dtype: float64
# 0    2.088900e+14
# Name: Market Cap, dtype: float64

# %%
cap = pd.DataFrame(cap, index = company_list)
cap
# Out:
#                 0
# TCB  1.815100e+14
# VCB  4.112600e+14
# SSI  4.452000e+13
# BVH  4.276000e+13
# VHM  3.457400e+14
# KBC  3.265000e+13
# MWG  9.824000e+13
# HAH  3.840000e+12
# GAS  2.239300e+14
# HPG  2.088900e+14

# %%
cap_weighted_port = pd.DataFrame(index=company_list, columns =['Market Cap','Weight','Beta','Adjbeta'])
cap_weighted_port['Market Cap'] = cap.values
cap_sum = sum(cap_weighted_port['Market Cap'])
cap_sum
# Out:
# 1593340000000000.0

# %%
for i in cap_weighted_port.index:
#    cap_weighted_port.loc[i,'Weight'] = cap_sum/cap_weighted_port.loc[i,'Market Cap']
    cap_weighted_port.loc[i, 'Weight'] =  round(cap_weighted_port.loc[i, 'Market Cap']/sum(cap_weighted_port['Market Cap']),4)
#cap_weighted_port['Weight'] = cap_weighted_port['Market Cap'].sum()

# %%
cap_weighted_port['Beta'] = df_beta.values
cap_weighted_port['Adjbeta'] = cap_weighted_port['Beta']*cap_weighted_port['Weight']
cap_weighted_port
# Out:
#        Market Cap  Weight     Beta   Adjbeta
# TCB  1.815100e+14  0.1139  1.26720  0.144334
# VCB  4.112600e+14  0.2581  0.92541  0.238848
# SSI  4.452000e+13  0.0279  1.69273  0.047227
# BVH  4.276000e+13  0.0268  1.07070  0.028695
# VHM  3.457400e+14   0.217  1.15963   0.25164
# KBC  3.265000e+13  0.0205  1.44860  0.029696
# MWG  9.824000e+13  0.0617  0.82737  0.051049
# HAH  3.840000e+12  0.0024  0.86995  0.002088
# GAS  2.239300e+14  0.1405  1.06322  0.149382
# HPG  2.088900e+14  0.1311  1.22213  0.160221

# %%
cap_weight_beta= cap_weighted_port['Adjbeta'].sum()
cap_weight_beta = 'Your portfolio beta is: '+ str(cap_weight_beta)+ ' which is made from '+ ', '.join(map(str, company_list))
cap_weight_beta
# Out:
# 'Your portfolio beta is: 1.1031806000000002 which is made from TCB, VCB, SSI, BVH, VHM, KBC, MWG, HAH, GAS, HPG'
